# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 150px; float: left;"> <img src="data/D4Sci_logo_ball.png" alt="Data For Science, Inc" align="left" border="0"> </div>
#     <div style="float: left; margin-left: 10px;"> <h1>NLP with PyTorch</h1>
# <h1>Neural Networks with PyTorch</h1>
#         <p>Bruno Gonçalves<br/>
#         <a href="http://www.data4sci.com/">www.data4sci.com</a><br/>
#             @bgoncalves, @data4sci</p></div>
# </div>

# %%
from collections import Counter
from pprint import pprint

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from tqdm.notebook import tqdm

import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import watermark

# %load_ext watermark
# %matplotlib inline

# %% [markdown]
# We start by print out the versions of the libraries we're using for future reference

# %%
# %watermark -n -v -m -g -iv
# Out:
# Python implementation: CPython
# Python version       : 3.10.18
# IPython version      : 8.38.0
#
# Compiler    : Clang 20.1.4
# OS          : Darwin
# Release     : 25.2.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 16
# Architecture: 64bit
#
# Git hash: 008980780627058467840b5f9dd419dfbb750104
#
# torchvision: 0.12.0
# torch      : 1.11.0
# watermark  : 2.4.3
# matplotlib : 3.10.8
# pandas     : 2.3.3
# numpy      : 1.26.4
# seaborn    : 0.13.2

# %% [markdown]
# Load default figure style

# %%
plt.style.use('d4sci.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# # Activation Functions

# %% [markdown]
# We start by defining a simple utility function to plot out the activation function

# %%
def plot_activation_function(activation_fn, x_range=(-6, 6), num_points=100):
    x = torch.linspace(x_range[0], x_range[1], num_points)
    x.requires_grad_(True)
    y = activation_fn(x)
    y.backward(torch.ones_like(x))
    gradient = x.grad
    
    fig, ax = plt.subplots(1)
    ax.plot(x.detach().numpy(), y.detach().numpy())
    ax.plot(x.detach().numpy(), gradient.detach().numpy())
    ax.set_xlabel('x')
    ax.legend(['Activation function', 'Gradient'])

# %% [markdown]
# And generate plots for a few examples:

# %% [markdown]
# #### Linear

# %%
plot_activation_function(torch.nn.Identity())

# %% [markdown]
# #### Sigmoid

# %%
plot_activation_function(torch.sigmoid)

# %% [markdown]
# #### Rectified Linear Unit

# %%
plot_activation_function(torch.relu)

# %% [markdown]
# #### Hyperbolic Tangent

# %%
plot_activation_function(torch.tanh)

# %% [markdown]
# # Simple Neural Network

# %% [markdown]
# We define a simple neural network by creating a new class that inherits form `nn.Module`:

# %%
class SimpleNet(nn.Module):
    def __init__(self, n_features):
        super(SimpleNet, self).__init__()
        # Linear regression with one output
        self.linear = nn.Linear(n_features, 1)  

    def forward(self, x):
        x = self.linear(x)
        return x

# %% [markdown]
# Next we load our dataset

# %%
anscombe = np.loadtxt('data/Anscombe1.dat', delimiter=' ')
anscombe = torch.from_numpy(anscombe).float()

# %% [markdown]
# And extract our instances and labels

# %%
X = anscombe[:, 0].reshape(-1, 1)
y = anscombe[:, 1].reshape(-1, 1)
n_features = X.shape[1]

# %%
X.shape
# Out:
# torch.Size([11, 1])

# %%
n_features
# Out:
# 1

# %% [markdown]
# Now we can instantiate our model

# %%
model = SimpleNet(n_features)

# %% [markdown]
# Defining the loss function and the optimizer are the next steps

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# Training loop

# %%
num_epochs = 2_000

for epoch in tqdm(range(num_epochs), total=num_epochs):
    # Forward pass
    outputs = model(X)
    loss = criterion(outputs, y)
    
    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# Extract model parameters

# %%
trained_params = model.state_dict()
print(trained_params)
# Out:
# OrderedDict([('linear.weight', tensor([[0.5352]])), ('linear.bias', tensor([2.6490]))])

# %% [markdown]
# And predictions

# %%
y_ = outputs.detach().numpy()

# %%
fig, ax = plt.subplots(1)
ax.plot(X, y, 
        marker='o', 
        markersize=10, 
        linestyle='None', 
        label='Data')

ax.plot(X, y_,
        linestyle='-', 
        label='Linear Regression')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(loc='lower right')

# %% [markdown]
# # Neural Network Classifier

# %% [markdown]
# Load the MNIST dataset

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# This will download the data the first time you run it and store it in the `data` folder
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# %% [markdown]
# Each data set is an array of tuples. The first element of the tuple is the image itself:

# %%
instance = 3
train_dataset[instance][0].shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# Which we can plot easily

# %%
fig, ax = plt.subplots(1)
ax.imshow(train_dataset[instance][0].squeeze(), cmap='gray')
ax.axis('off')
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %% [markdown]
# The second element is the label

# %%
print(f"This is a picture of the number: {train_dataset[instance][1]}")
# Out:
# This is a picture of the number: 1

# %% [markdown]
# We have examples of all digits

# %%
fig, axs_lst = plt.subplots(2, 5, figsize=(14, 5.6))
axs_lst = np.array(axs_lst).flatten()

instances = [1, 3, 5, 7, 2, 0, 13, 15, 17, 19]

for i, instance in enumerate(instances):
    axs_lst[i].imshow(train_dataset[instance][0].squeeze(), cmap='gray')
    axs_lst[i].set_title(train_dataset[instance][1])
    axs_lst[i].axis('off')

fig.tight_layout()

# %%
hist_train = Counter([train_dataset[i][1] for i in range(len(train_dataset))])
hist_train = pd.DataFrame.from_dict(hist_train.items())
hist_train.columns = ['Number', 'Frequency']

hist_test = Counter([test_dataset[i][1] for i in range(len(test_dataset))])
hist_test = pd.DataFrame.from_dict(hist_test.items())
hist_test.columns = ['Number', 'Frequency']

# %%
fig, ax = plt.subplots(1)
ax.bar(hist_train['Number']-0.15, hist_train['Frequency'], width=0.3)
ax.bar(hist_test['Number']+0.15, hist_test['Frequency'], width=0.3)
ax.set_xlabel('Digits')
ax.set_xticks(range(10))
ax.set_xticklabels(range(10))
ax.set_ylabel('Count')
ax.set_yticklabels([f'{int(label):,}' for label in ax.get_yticks()])
ax.legend(['Train', 'Test'])
# Out:
# /var/folders/lr/j1bs1q851k15cj5y777nxwph0000gn/T/ipykernel_31428/4174146417.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([f'{int(label):,}' for label in ax.get_yticks()])

# %% [markdown]
# Define the network architecture

# %%
class MNISTClassifier1(nn.Module):
    def __init__(self):
        super(MNISTClassifier1, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)
    
    def forward(self, x):
        x0 = x.view(-1, 28*28)  # Flatten the input
        x1 = torch.relu(self.fc1(x0))
        x2 = torch.relu(self.fc2(x1))
        x3 = self.fc3(x2)
        
        return torch.sigmoid(x3)

# %% [markdown]
# Define the neural network architecture using `nn.Sequential`

# %%
class MNISTClassifier(nn.Module):
    def __init__(self):
        super(MNISTClassifier, self).__init__()
        # Define the layers
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 64)

        # Build the model
        self.network = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        x = x.view(-1, 28*28)  # Flatten the input
        x = self.network(x)
        return x

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=True)

# %%
model = MNISTClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.002)

# %%
# Training loop
num_epochs = 20
history = {'train_loss': [], 'train_acc': [], 'test_acc': []}

for epoch in tqdm(range(num_epochs), total=num_epochs):
    model.train()
    
    for images, labels in train_loader:
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    model.eval()

    with torch.no_grad():
        test_correct = 0
        test_total = 0

        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

        train_correct = 0
        train_total = 0

        for images, labels in train_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()

    history['train_loss'].append(loss.item())
    history['train_acc'].append(100 * train_correct / train_total)
    history['test_acc'].append(100 * test_correct / test_total)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}  Training Accuracy: {100 * train_correct / train_total:.2f}% Testing Accuracy: {100 * test_correct / test_total:.2f}%')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [1/20], Loss: 1.5572  Training Accuracy: 91.94% Testing Accuracy: 92.15%
# Epoch [2/20], Loss: 1.5258  Training Accuracy: 94.37% Testing Accuracy: 94.25%
# Epoch [3/20], Loss: 1.4844  Training Accuracy: 95.21% Testing Accuracy: 94.91%
# Epoch [4/20], Loss: 1.4917  Training Accuracy: 96.02% Testing Accuracy: 95.84%
# Epoch [5/20], Loss: 1.4796  Training Accuracy: 96.31% Testing Accuracy: 95.83%
# Epoch [6/20], Loss: 1.4908  Training Accuracy: 96.67% Testing Accuracy: 96.25%
# Epoch [7/20], Loss: 1.5189  Training Accuracy: 97.27% Testing Accuracy: 96.66%
# Epoch [8/20], Loss: 1.4663  Training Accuracy: 97.14% Testing Accuracy: 96.47%
# Epoch [9/20], Loss: 1.4924  Training Accuracy: 96.92% Testing Accuracy: 96.25%
# Epoch [10/20], Loss: 1.4702  Training Accuracy: 97.53% Testing Accuracy: 96.93%
# Epoch [11/20], Loss: 1.4962  Training Accuracy: 97.14% Testing Accuracy: 96.49%
# Epoch [12/20], Loss: 1.5045  Training Accuracy: 97.57% Testing Accuracy: 97.03%
# Epoch [13/20], Loss: 1.4735  Training Accuracy: 97.40% Testing Accuracy: 96.42%
# Epoch [14/20], Loss: 1.4965  Training Accuracy: 97.69% Testing Accuracy: 97.03%
# Epoch [15/20], Loss: 1.4999  Training Accuracy: 97.63% Testing Accuracy: 96.75%
# Epoch [16/20], Loss: 1.4899  Training Accuracy: 97.92% Testing Accuracy: 96.98%
# Epoch [17/20], Loss: 1.4816  Training Accuracy: 97.88% Testing Accuracy: 97.20%
# Epoch [18/20], Loss: 1.4805  Training Accuracy: 97.43% Testing Accuracy: 96.71%
# Epoch [19/20], Loss: 1.4898  Training Accuracy: 97.94% Testing Accuracy: 97.02%
# Epoch [20/20], Loss: 1.4740  Training Accuracy: 97.70% Testing Accuracy: 97.07%

# %%
fig, ax = plt.subplots(1)
ax.plot(history['train_acc'], label='Training')
ax.plot(history['test_acc'], label='Testing')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend()
ax.set_xticks(range(num_epochs));

# %% [markdown]
# <center>
#      <img src="data/D4Sci_logo_full.png" alt="Data For Science, Inc" border="0" width=300px>
# </center>
