# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 150px; float: left;"> <img src="data/D4Sci_logo_ball.png" alt="Data For Science, Inc" align="left" border="0"> </div>
#     <div style="float: left; margin-left: 10px;"> <h1>NLP with PyTorch</h1>
# <h1>Neural Networks with PyTorch</h1>
#         <p>Bruno Gonçalves<br/>
#         <a href="http://www.data4sci.com/">www.data4sci.com</a><br/>
#             @bgoncalves, @data4sci</p></div>
# </div>

# %%
from collections import Counter
from pprint import pprint

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from tqdm.notebook import tqdm

import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import watermark

# %load_ext watermark
# %matplotlib inline

# %% [markdown]
# We start by print out the versions of the libraries we're using for future reference

# %%
# %watermark -n -v -m -g -iv
# Out:
# Python implementation: CPython
# Python version       : 3.10.18
# IPython version      : 8.38.0
#
# Compiler    : Clang 20.1.4
# OS          : Darwin
# Release     : 25.2.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 16
# Architecture: 64bit
#
# Git hash: 1ffc90870b4477639ef2f2f30e47667ac9ef9535
#
# watermark  : 2.4.3
# numpy      : 1.26.4
# pandas     : 2.3.3
# torchvision: 0.18.1
# matplotlib : 3.10.8
# torch      : 2.3.1
# seaborn    : 0.13.2

# %% [markdown]
# Load default figure style

# %%
plt.style.use('d4sci.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# # Activation Functions

# %% [markdown]
# We start by defining a simple utility function to plot out the activation function

# %%
def plot_activation_function(activation_fn, x_range=(-6, 6), num_points=100):
    x = torch.linspace(x_range[0], x_range[1], num_points)
    x.requires_grad_(True)
    y = activation_fn(x)
    y.backward(torch.ones_like(x))
    gradient = x.grad
    
    fig, ax = plt.subplots(1)
    ax.plot(x.detach().numpy(), y.detach().numpy())
    ax.plot(x.detach().numpy(), gradient.detach().numpy())
    ax.set_xlabel('x')
    ax.legend(['Activation function', 'Gradient'])

# %% [markdown]
# And generate plots for a few examples:

# %% [markdown]
# #### Linear

# %%
plot_activation_function(torch.nn.Identity())

# %% [markdown]
# #### Sigmoid

# %%
plot_activation_function(torch.sigmoid)

# %% [markdown]
# #### Rectified Linear Unit

# %%
plot_activation_function(torch.relu)

# %% [markdown]
# #### Hyperbolic Tangent

# %%
plot_activation_function(torch.tanh)

# %% [markdown]
# # Simple Neural Network

# %% [markdown]
# We define a simple neural network by creating a new class that inherits form `nn.Module`:

# %%
class SimpleNet(nn.Module):
    def __init__(self, n_features):
        super(SimpleNet, self).__init__()
        
        # Linear regression with one output
        self.linear = nn.Linear(n_features, 1)  

    def forward(self, x):
        x = self.linear(x)
        return x

# %% [markdown]
# Next we load our dataset

# %%
anscombe = np.loadtxt('data/Anscombe1.dat', delimiter=' ')
anscombe = torch.from_numpy(anscombe).float()

# %% [markdown]
# And extract our instances and labels

# %%
X = anscombe[:, 0].reshape(-1, 1)
y = anscombe[:, 1].reshape(-1, 1)
n_features = X.shape[1]

# %%
X.shape
# Out:
# torch.Size([11, 1])

# %%
n_features
# Out:
# 1

# %% [markdown]
# Now we can instantiate our model

# %%
model = SimpleNet(n_features)

# %% [markdown]
# Defining the loss function and the optimizer are the next steps

# %%
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# Training loop

# %%
num_epochs = 2_000

for epoch in tqdm(range(num_epochs), total=num_epochs):
    # Forward pass
    outputs = model(X)
    error = loss(outputs, y)
    
    # Backward pass and optimization
    optimizer.zero_grad()
    error.backward()
    optimizer.step()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# Extract model parameters

# %%
trained_params = model.state_dict()
print(trained_params)
# Out:
# OrderedDict([('linear.weight', tensor([[0.5020]])), ('linear.bias', tensor([2.9811]))])

# %% [markdown]
# And predictions

# %%
y_ = outputs.detach().numpy()

# %%
fig, ax = plt.subplots(1)
ax.plot(X, y, 
        marker='o', 
        markersize=10, 
        linestyle='None', 
        label='Data')

ax.plot(X, y_,
        linestyle='-', 
        label='Linear Regression')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(loc='lower right')

# %% [markdown]
# # Neural Network Classifier

# %% [markdown]
# Load the MNIST dataset

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# This will download the data the first time you run it and store it in the `data` folder
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# %% [markdown]
# Each data set is an array of tuples. The first element of the tuple is the image itself:

# %%
instance = 3
train_dataset[instance][0].shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# Which we can plot easily

# %%
fig, ax = plt.subplots(1)
ax.imshow(train_dataset[instance][0].squeeze(), cmap='gray')
ax.axis('off')
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %% [markdown]
# The second element is the label

# %%
print(f"This is a picture of the number: {train_dataset[instance][1]}")
# Out:
# This is a picture of the number: 1

# %% [markdown]
# We have examples of all digits

# %%
fig, axs_lst = plt.subplots(2, 5, figsize=(14, 5.6))
axs_lst = np.array(axs_lst).flatten()

instances = [1, 3, 5, 7, 2, 0, 13, 15, 17, 19]

for i, instance in enumerate(instances):
    axs_lst[i].imshow(train_dataset[instance][0].squeeze(), cmap='gray')
    axs_lst[i].set_title(train_dataset[instance][1])
    axs_lst[i].axis('off')

fig.tight_layout()

# %%
hist_train = Counter([train_dataset[i][1] for i in range(len(train_dataset))])
hist_train = pd.DataFrame.from_dict(hist_train.items())
hist_train.columns = ['Number', 'Frequency']

hist_test = Counter([test_dataset[i][1] for i in range(len(test_dataset))])
hist_test = pd.DataFrame.from_dict(hist_test.items())
hist_test.columns = ['Number', 'Frequency']

# %%
fig, ax = plt.subplots(1)
ax.bar(hist_train['Number']-0.15, hist_train['Frequency'], width=0.3)
ax.bar(hist_test['Number']+0.15, hist_test['Frequency'], width=0.3)
ax.set_xlabel('Digits')
ax.set_xticks(range(10))
ax.set_xticklabels(range(10))
ax.set_ylabel('Count')
ax.set_yticklabels([f'{int(label):,}' for label in ax.get_yticks()])
ax.legend(['Train', 'Test'])
# Out:
# /var/folders/lr/j1bs1q851k15cj5y777nxwph0000gn/T/ipykernel_56530/4174146417.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([f'{int(label):,}' for label in ax.get_yticks()])

# %% [markdown]
# Define the network architecture

# %%
class MNISTClassifier1(nn.Module):
    def __init__(self):
        super(MNISTClassifier1, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)
    
    def forward(self, x):
        x0 = x.view(-1, 28*28)  # Flatten the input
        x1 = torch.relu(self.fc1(x0))
        x2 = torch.relu(self.fc2(x1))
        x3 = torch.sigmoid(self.fc3(x2))
        
        return x3

# %% [markdown]
# Define the neural network architecture using `nn.Sequential`

# %%
class MNISTClassifier(nn.Module):
    def __init__(self):
        super(MNISTClassifier, self).__init__()
        # Define the layers
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 64)

        # Build the model
        self.network = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        x0 = x.view(-1, 28*28)  # Flatten the input
        x = self.network(x0)
        return x

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=True)

# %%
model = MNISTClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.002)

# %% [markdown]
# ## Training loop

# %%
num_epochs = 20
history = {'train_loss': [], 'train_acc': [], 'test_acc': []}

for epoch in tqdm(range(num_epochs), total=num_epochs):
    model.train()
    
    for images, labels in train_loader:
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    model.eval()

    with torch.no_grad():
        test_correct = 0
        test_total = 0

        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

        train_correct = 0
        train_total = 0

        for images, labels in train_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()

    history['train_loss'].append(loss.item())
    history['train_acc'].append(100 * train_correct / train_total)
    history['test_acc'].append(100 * test_correct / test_total)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}  Training Accuracy: {100 * train_correct / train_total:.2f}% Testing Accuracy: {100 * test_correct / test_total:.2f}%')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [1/20], Loss: 1.5615  Training Accuracy: 91.08% Testing Accuracy: 91.52%
# Epoch [2/20], Loss: 1.5044  Training Accuracy: 93.63% Testing Accuracy: 93.23%
# Epoch [3/20], Loss: 1.5691  Training Accuracy: 94.46% Testing Accuracy: 94.31%
# Epoch [4/20], Loss: 1.4955  Training Accuracy: 95.84% Testing Accuracy: 95.58%
# Epoch [5/20], Loss: 1.4938  Training Accuracy: 96.63% Testing Accuracy: 96.29%
# Epoch [6/20], Loss: 1.4965  Training Accuracy: 96.60% Testing Accuracy: 96.08%
# Epoch [7/20], Loss: 1.4793  Training Accuracy: 97.01% Testing Accuracy: 96.29%
# Epoch [8/20], Loss: 1.4701  Training Accuracy: 96.97% Testing Accuracy: 96.25%
# Epoch [9/20], Loss: 1.4934  Training Accuracy: 97.39% Testing Accuracy: 96.75%
# Epoch [10/20], Loss: 1.4781  Training Accuracy: 97.20% Testing Accuracy: 96.61%
# Epoch [11/20], Loss: 1.5044  Training Accuracy: 97.43% Testing Accuracy: 96.88%
# Epoch [12/20], Loss: 1.5006  Training Accuracy: 96.96% Testing Accuracy: 96.40%
# Epoch [13/20], Loss: 1.4822  Training Accuracy: 97.48% Testing Accuracy: 96.80%
# Epoch [14/20], Loss: 1.4724  Training Accuracy: 97.64% Testing Accuracy: 96.80%
# Epoch [15/20], Loss: 1.5000  Training Accuracy: 97.40% Testing Accuracy: 96.60%
# Epoch [16/20], Loss: 1.4769  Training Accuracy: 97.78% Testing Accuracy: 96.94%
# Epoch [17/20], Loss: 1.4782  Training Accuracy: 98.16% Testing Accuracy: 97.36%
# Epoch [18/20], Loss: 1.4867  Training Accuracy: 97.89% Testing Accuracy: 97.01%
# Epoch [19/20], Loss: 1.4756  Training Accuracy: 97.81% Testing Accuracy: 96.78%
# Epoch [20/20], Loss: 1.4677  Training Accuracy: 98.01% Testing Accuracy: 97.31%

# %%
fig, ax = plt.subplots(1)
ax.plot(history['train_acc'], label='Training')
ax.plot(history['test_acc'], label='Testing')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend()
ax.set_xticks(range(num_epochs));

# %% [markdown]
# <center>
#      <img src="data/D4Sci_logo_full.png" alt="Data For Science, Inc" border="0" width=300px>
# </center>
